# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/concrete_data.csv')
df.head()
# Out:
#    cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0   540.0    0.0     0.0  162.0               2.5           1040.0
# 1   540.0    0.0     0.0  162.0               2.5           1055.0
# 2   332.5  142.5     0.0  228.0               0.0            932.0
# 3   332.5  142.5     0.0  228.0               0.0            932.0
# 4   198.6  132.4     0.0  192.0               0.0            978.4
#
#    fineaggregate  age  csMPa
# 0          676.0   28  79.99
# 1          676.0   28  61.89
# 2          594.0  270  40.27
# 3          594.0  365  41.05
# 4          825.5  360  44.30

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns='csMPa')
y = df.csMPa
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((824, 8), (206, 8), (824,), (206,))

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor

ada_reg = AdaBoostRegressor(
    DecisionTreeRegressor(max_depth=4),
    n_estimators=100,
    learning_rate=1.0,
)
ada_reg.fit(X_train, y_train)
print(f'Train Score: {ada_reg.score(X_train, y_train):.2f}')
print(f'Test Score: {ada_reg.score(X_test, y_test):.2f}')
# Out:
# Train Score: 0.87
# Test Score: 0.83

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor

ada_reg = AdaBoostRegressor(
    DecisionTreeRegressor(max_depth=2),
    n_estimators=200,
    learning_rate=0.5,
)
ada_reg.fit(X_train, y_train)
print(f'Train Score: {ada_reg.score(X_train, y_train):.2f}')
print(f'Test Score: {ada_reg.score(X_test, y_test):.2f}')
# Out:
# Train Score: 0.74
# Test Score: 0.72

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor(
    max_depth=4,
    n_estimators=100,
    learning_rate=0.1,
)
gbr.fit(X_train, y_train)
print(f'Train Score: {gbr.score(X_train, y_train):.2f}')
print(f'Test Score: {gbr.score(X_test, y_test):.2f}')
# Out:
# Train Score: 0.97
# Test Score: 0.92

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score, mean_squared_error

gbr = GradientBoostingRegressor(max_depth=3)
params = dict(n_estimators=[50, 100, 200, 500, 1000], learning_rate=[0.1, 0.5, 1.0])
grid = GridSearchCV(gbr, params, cv=3, scoring='neg_mean_squared_error')
grid.fit(X_train, y_train)
y_pred = grid.predict(X_test)
print(f'Train Score: {r2_score(y_train, grid.predict(X_train)):.2f}')
print(f'Test Score: {r2_score(y_test, y_pred):.2f}')
# Out:
# Train Score: 0.99
# Test Score: 0.94

# %%
print(grid.best_params_)
# Out:
# {'learning_rate': 0.1, 'n_estimators': 1000}

# %%
# Warm Start and Early Stopping
gbr = GradientBoostingRegressor(max_depth=3, warm_start=True)

min_val_error = float('inf')
error_going_up = 0

for n_estimators in range(1, 1000):
    gbr.n_estimators = n_estimators
    gbr.fit(X_train, y_train)
    
    y_pred = gbr.predict(X_test)
    val_error = mean_squared_error(y_test, y_pred)

    print(f'n_estimators: {n_estimators}, val_error: {val_error:.4f}')

    if val_error < min_val_error:
        min_val_error = val_error
        error_going_up = 0
    else:
        error_going_up += 1
        if error_going_up == 10: # early stopping
            break
# Out:
# n_estimators: 1, val_error: 232.4961
# n_estimators: 2, val_error: 206.6208
# n_estimators: 3, val_error: 182.4964
# n_estimators: 4, val_error: 162.1774
# n_estimators: 5, val_error: 146.6245
# n_estimators: 6, val_error: 132.8427
# n_estimators: 7, val_error: 121.5462
# n_estimators: 8, val_error: 113.6059
# n_estimators: 9, val_error: 105.3829
# n_estimators: 10, val_error: 98.9242
# n_estimators: 11, val_error: 91.7530
# n_estimators: 12, val_error: 85.1065
# n_estimators: 13, val_error: 79.9572
# n_estimators: 14, val_error: 75.8880
# n_estimators: 15, val_error: 71.8108
# n_estimators: 16, val_error: 68.6884
# n_estimators: 17, val_error: 65.0228
# n_estimators: 18, val_error: 62.4262
# n_estimators: 19, val_error: 60.0161
# n_estimators: 20, val_error: 57.3311
# n_estimators: 21, val_error: 55.1957
# n_estimators: 22, val_error: 53.2125
# n_estimators: 23, val_error: 51.6198
# n_estimators: 24, val_error: 49.7197
# n_estimators: 25, val_error: 48.3067
# n_estimators: 26, val_error: 46.9188
# n_estimators: 27, val_error: 45.5018
# n_estimators: 28, val_error: 44.0429
# n_estimators: 29, val_error: 42.9901
# n_estimators: 30, val_error: 42.0497
# n_estimators: 31, val_error: 41.0468
# n_estimators: 32, val_error: 40.2060
# n_estimators: 33, val_error: 39.5790
# n_estimators: 34, val_error: 38.8823
# n_estimators: 35, val_error: 37.8929
# n_estimators: 36, val_error: 37.1905
# n_estimators: 37, val_error: 36.3231
# n_estimators: 38, val_error: 35.5935
# n_estimators: 39, val_error: 35.0254
# n_estimators: 40, val_error: 34.7502
# n_estimators: 41, val_error: 34.1798
# n_estimators: 42, val_error: 33.9294
# n_estimators: 43, val_error: 33.6665
# n_estimators: 44, val_error: 33.3461
# n_estimators: 45, val_error: 33.0452
# n_estimators: 46, val_error: 32.7516
# n_estimators: 47, val_error: 32.4129
# n_estimators: 48, val_error: 32.1791
# n_estimators: 49, val_error: 31.9090
# n_estimators: 50, val_error: 31.6844
# n_estimators: 51, val_error: 31.4122
# n_estimators: 52, val_error: 31.0256
# n_estimators: 53, val_error: 30.7332
# n_estimators: 54, val_error: 30.3651
# n_estimators: 55, val_error: 30.1113
# n_estimators: 56, val_error: 30.0748
# n_estimators: 57, val_error: 30.0296
# n_estimators: 58, val_error: 29.8984
# n_estimators: 59, val_error: 29.5773
# n_estimators: 60, val_error: 29.4243
# n_estimators: 61, val_error: 29.2230
# n_estimators: 62, val_error: 28.9913
# n_estimators: 63, val_error: 28.7846
# n_estimators: 64, val_error: 28.5904
# n_estimators: 65, val_error: 28.4590
# n_estimators: 66, val_error: 28.2553
# n_estimators: 67, val_error: 28.0138
# n_estimators: 68, val_error: 27.9723
# n_estimators: 69, val_error: 27.6256
# n_estimators: 70, val_error: 27.4590
# n_estimators: 71, val_error: 27.2327
# n_estimators: 72, val_error: 27.2699
# n_estimators: 73, val_error: 27.2163
# n_estimators: 74, val_error: 27.0664
# n_estimators: 75, val_error: 27.0279
# n_estimators: 76, val_error: 26.9145
# n_estimators: 77, val_error: 26.7659
# n_estimators: 78, val_error: 26.7440
# n_estimators: 79, val_error: 26.7446
# n_estimators: 80, val_error: 26.5672
# n_estimators: 81, val_error: 26.3973
# n_estimators: 82, val_error: 26.3830
# n_estimators: 83, val_error: 26.3887
# n_estimators: 84, val_error: 26.2390
# n_estimators: 85, val_error: 26.1344
# n_estimators: 86, val_error: 25.9089
# n_estimators: 87, val_error: 25.7169
# n_estimators: 88, val_error: 25.5987
# n_estimators: 89, val_error: 25.4442
# n_estimators: 90, val_error: 25.3585
# n_estimators: 91, val_error: 25.3833
# n_estimators: 92, val_error: 25.2906
# n_estimators: 93, val_error: 25.1484
# n_estimators: 94, val_error: 25.1357
# n_estimators: 95, val_error: 25.0228
# n_estimators: 96, val_error: 24.8971
# n_estimators: 97, val_error: 24.8800
# n_estimators: 98, val_error: 24.8793
# n_estimators: 99, val_error: 24.8038
# n_estimators: 100, val_error: 24.7541
# n_estimators: 101, val_error: 24.5250
# n_estimators: 102, val_error: 24.5018
# n_estimators: 103, val_error: 24.3354
# n_estimators: 104, val_error: 24.2850
# n_estimators: 105, val_error: 24.2583
# n_estimators: 106, val_error: 24.2216
# n_estimators: 107, val_error: 24.0221
# n_estimators: 108, val_error: 23.9830
# n_estimators: 109, val_error: 23.7934
# n_estimators: 110, val_error: 23.7529
# n_estimators: 111, val_error: 23.6660
# n_estimators: 112, val_error: 23.6243
# n_estimators: 113, val_error: 23.5523
# n_estimators: 114, val_error: 23.5475
# n_estimators: 115, val_error: 23.5578
# n_estimators: 116, val_error: 23.5547
# n_estimators: 117, val_error: 23.4971
# n_estimators: 118, val_error: 23.5918
# n_estimators: 119, val_error: 23.5365
# n_estimators: 120, val_error: 23.4856
# n_estimators: 121, val_error: 23.4891
# n_estimators: 122, val_error: 23.4193
# n_estimators: 123, val_error: 23.3478
# n_estimators: 124, val_error: 23.3231
# n_estimators: 125, val_error: 23.3742
# n_estimators: 126, val_error: 23.3331
# n_estimators: 127, val_error: 23.3334
# n_estimators: 128, val_error: 23.2691
# n_estimators: 129, val_error: 23.2518
# n_estimators: 130, val_error: 23.1754
# n_estimators: 131, val_error: 23.1068
# n_estimators: 132, val_error: 23.0020
# n_estimators: 133, val_error: 23.0022
# n_estimators: 134, val_error: 22.8675
# n_estimators: 135, val_error: 22.7474
# n_estimators: 136, val_error: 22.6906
# n_estimators: 137, val_error: 22.6328
# n_estimators: 138, val_error: 22.6279
# n_estimators: 139, val_error: 22.5787
# n_estimators: 140, val_error: 22.5777
# n_estimators: 141, val_error: 22.6272
# n_estimators: 142, val_error: 22.5224
# n_estimators: 143, val_error: 22.5069
# n_estimators: 144, val_error: 22.5027
# n_estimators: 145, val_error: 22.4157
# n_estimators: 146, val_error: 22.3683
# n_estimators: 147, val_error: 22.3450
# n_estimators: 148, val_error: 22.2943
# n_estimators: 149, val_error: 22.2766
# n_estimators: 150, val_error: 22.2626
# n_estimators: 151, val_error: 22.2419
# n_estimators: 152, val_error: 22.2471
# n_estimators: 153, val_error: 22.2402
# n_estimators: 154, val_error: 22.1642
# n_estimators: 155, val_error: 21.9650
# n_estimators: 156, val_error: 21.9381
# n_estimators: 157, val_error: 21.9142
# n_estimators: 158, val_error: 21.9084
# n_estimators: 159, val_error: 21.8962
# n_estimators: 160, val_error: 21.8955
# n_estimators: 161, val_error: 21.7993
# n_estimators: 162, val_error: 21.7538
# n_estimators: 163, val_error: 21.7143
# n_estimators: 164, val_error: 21.6473
# n_estimators: 165, val_error: 21.6508
# n_estimators: 166, val_error: 21.5790
# n_estimators: 167, val_error: 21.5769
# n_estimators: 168, val_error: 21.5500
# n_estimators: 169, val_error: 21.4986
# n_estimators: 170, val_error: 21.4853
# n_estimators: 171, val_error: 21.4295
# n_estimators: 172, val_error: 21.3963
# n_estimators: 173, val_error: 21.3962
# n_estimators: 174, val_error: 21.2740
# n_estimators: 175, val_error: 21.1996
# n_estimators: 176, val_error: 21.2107
# n_estimators: 177, val_error: 21.2140
# n_estimators: 178, val_error: 21.1348
# n_estimators: 179, val_error: 21.0574
# n_estimators: 180, val_error: 21.0672
# n_estimators: 181, val_error: 21.0690
# n_estimators: 182, val_error: 21.0409
# n_estimators: 183, val_error: 21.0411
# n_estimators: 184, val_error: 21.0109
# n_estimators: 185, val_error: 20.9993
# n_estimators: 186, val_error: 21.0039
# n_estimators: 187, val_error: 21.0018
# n_estimators: 188, val_error: 21.0043
# n_estimators: 189, val_error: 20.9280
# n_estimators: 190, val_error: 20.9041
# n_estimators: 191, val_error: 20.9017
# n_estimators: 192, val_error: 20.8909
# n_estimators: 193, val_error: 20.8898
# n_estimators: 194, val_error: 20.8500
# n_estimators: 195, val_error: 20.8502
# n_estimators: 196, val_error: 20.8466
# n_estimators: 197, val_error: 20.7854
# n_estimators: 198, val_error: 20.7412
# n_estimators: 199, val_error: 20.7085
# n_estimators: 200, val_error: 20.6979
# n_estimators: 201, val_error: 20.7050
# n_estimators: 202, val_error: 20.6686
# n_estimators: 203, val_error: 20.6329
# n_estimators: 204, val_error: 20.6203
# n_estimators: 205, val_error: 20.6413
# n_estimators: 206, val_error: 20.6153
# n_estimators: 207, val_error: 20.6092
# n_estimators: 208, val_error: 20.5586
# n_estimators: 209, val_error: 20.5493
# n_estimators: 210, val_error: 20.4703
# n_estimators: 211, val_error: 20.4540
# n_estimators: 212, val_error: 20.4455
# n_estimators: 213, val_error: 20.3898
# n_estimators: 214, val_error: 20.3213
# n_estimators: 215, val_error: 20.3398
# n_estimators: 216, val_error: 20.2922
# n_estimators: 217, val_error: 20.2834
# n_estimators: 218, val_error: 20.2632
# n_estimators: 219, val_error: 20.2665
# n_estimators: 220, val_error: 20.2302
# n_estimators: 221, val_error: 20.1736
# n_estimators: 222, val_error: 20.0301
# n_estimators: 223, val_error: 20.0288
# n_estimators: 224, val_error: 19.9867
# n_estimators: 225, val_error: 19.9861
# n_estimators: 226, val_error: 19.9115
# n_estimators: 227, val_error: 19.9251
# n_estimators: 228, val_error: 19.9252
# n_estimators: 229, val_error: 19.9052
# n_estimators: 230, val_error: 19.8869
# n_estimators: 231, val_error: 19.8804
# n_estimators: 232, val_error: 19.8929
# n_estimators: 233, val_error: 19.8259
# n_estimators: 234, val_error: 19.8275
# n_estimators: 235, val_error: 19.7938
# n_estimators: 236, val_error: 19.7790
# n_estimators: 237, val_error: 19.7567
# n_estimators: 238, val_error: 19.7398
# n_estimators: 239, val_error: 19.6605
# n_estimators: 240, val_error: 19.6179
# n_estimators: 241, val_error: 19.5656
# n_estimators: 242, val_error: 19.5883
# n_estimators: 243, val_error: 19.5548
# n_estimators: 244, val_error: 19.5972
# n_estimators: 245, val_error: 19.5776
# n_estimators: 246, val_error: 19.6025
# n_estimators: 247, val_error: 19.5834
# n_estimators: 248, val_error: 19.4779
# n_estimators: 249, val_error: 19.4648
# n_estimators: 250, val_error: 19.4672
# n_estimators: 251, val_error: 19.4554
# n_estimators: 252, val_error: 19.4550
# n_estimators: 253, val_error: 19.3901
# n_estimators: 254, val_error: 19.3544
# n_estimators: 255, val_error: 19.3544
# n_estimators: 256, val_error: 19.3538
# n_estimators: 257, val_error: 19.3533
# n_estimators: 258, val_error: 19.3523
# n_estimators: 259, val_error: 19.3491
# n_estimators: 260, val_error: 19.3198
# n_estimators: 261, val_error: 19.2761
# n_estimators: 262, val_error: 19.2638
# n_estimators: 263, val_error: 19.2545
# n_estimators: 264, val_error: 19.2721
# n_estimators: 265, val_error: 19.2728
# n_estimators: 266, val_error: 19.2704
# n_estimators: 267, val_error: 19.3472
# n_estimators: 268, val_error: 19.3632
# n_estimators: 269, val_error: 19.3528
# n_estimators: 270, val_error: 19.3305
# n_estimators: 271, val_error: 19.3285
# n_estimators: 272, val_error: 19.3069
# n_estimators: 273, val_error: 19.2727

# %%
gbr = GradientBoostingRegressor(max_depth=3, n_estimators=n_estimators)
gbr.fit(X_train, y_train)
y_pred = gbr.predict(X_test)
print(f'Train Score: {gbr.score(X_train, y_train):.2f}')
print(f'Test Score: {gbr.score(X_test, y_test):.2f}')
# Out:
# Train Score: 0.98
# Test Score: 0.93
